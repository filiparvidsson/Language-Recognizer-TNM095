# %% [markdown]
# # Spoken Language Recognition Using Convolutional Neural Networks
#
# _written by Joscha S. Rieber (Fraunhofer IAIS) in 2020_

# %% [markdown]
# ## Environment

# %%
train = 'train'
test = 'test'

eng = 'english'
ger = 'german'
ita = 'italian'
#swe = 'swedish'

languages = [eng, ger, ita]
categories = [train, test]

dataset_root_path = '../data/'

image_width = 500
image_height = 128

augment_data_factor = 1.0 # Set-up how much of the training data should be augmented

# %% [markdown]
# ## Import Libraries

# %%
import os
import librosa as lr
#from librosa.display import waveplot
import librosa.display
import numpy as np
from glob import glob
import matplotlib.pyplot as plt
import warnings
from IPython.display import Audio
import soundfile as sf

# %% [markdown]
# ## Helper Functions

# %% [markdown]
# ### Function for loading the audio file

# %%
def load_audio_file(audio_file_path):
    warnings.simplefilter('ignore', UserWarning)
    
    audio_segment, sample_rate = lr.load(audio_file_path)
    return audio_segment, sample_rate

    warnings.simplefilter('default', UserWarning)

# %% [markdown]
# ### Functions for data augmentation

# %%
def add_noise(audio_segment, gain):
    num_samples = audio_segment.shape[0]
    noise = gain * np.random.normal(size=num_samples)
    return audio_segment + noise

# %% [markdown]
# ### Determine all available audio files

# %%
audio_files = {}

for lang in languages:
    for category in categories:
        audio_files[lang + '.' + category] = glob(dataset_root_path + category + '/' + lang + '/*.mp3')

print(audio_files.keys())
# Out:
# dict_keys(['english.train', 'english.test', 'german.train', 'german.test', 'italian.train', 'italian.test'])

# %% [markdown]
# ## Example

# %%
key = list(audio_files.keys())[1]
audio_file = audio_files[key][1]
audio_file
# Out:
# '../data/test/english\\common_voice_en_10056752.mp3'

# %%
audio, sample_rate = load_audio_file(audio_file)

Audio(audio, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio_segment_with_noise = add_noise(audio, 0.005)

Audio(audio_segment_with_noise, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Augment training dataset

# %%
def augment_audio_file_with_noise(audio_file_path):
    audio_segment, sample_rate = load_audio_file(audio_file_path)
    audio_segment_with_noise = add_noise(audio_segment, 0.005)
    audio_file_path_without_extension = os.path.splitext(audio_file_path)[0]
    augmented_audio_file_path = audio_file_path_without_extension + '_augmented_noise.wav'
    sf.write(augmented_audio_file_path, audio_segment_with_noise, sample_rate)

# %%
for lang in languages:
    category = train
        
    all_audio_files = audio_files[lang + '.' + category]
        
    num_files = int(len(all_audio_files) * augment_data_factor)

    for i in range(num_files):
        if i % (num_files / 10) == 0:
            print('Still processing ' + lang + ' ' + category + ' ' + str(i) + '/' + str(num_files))
        augment_audio_file_with_noise(all_audio_files[i])
# Out:
# Still processing english train 0/8000
# Still processing english train 800/8000
# Still processing english train 1600/8000
# Still processing english train 2400/8000
# Still processing english train 3200/8000
# Still processing english train 4000/8000
# Still processing english train 4800/8000
# Still processing english train 5600/8000
# Still processing english train 6400/8000
# Still processing english train 7200/8000
# Still processing german train 0/8000
# Still processing german train 800/8000
# Still processing german train 1600/8000
# Still processing german train 2400/8000
# Still processing german train 3200/8000
# Still processing german train 4000/8000
# Still processing german train 4800/8000
# Still processing german train 5600/8000
# Still processing german train 6400/8000
# Still processing german train 7200/8000
# Still processing italian train 0/8000
# Still processing italian train 800/8000
# Still processing italian train 1600/8000
# Still processing italian train 2400/8000
# Still processing italian train 3200/8000
# Still processing italian train 4000/8000
# Still processing italian train 4800/8000
# Still processing italian train 5600/8000
# Still processing italian train 6400/8000
# Still processing italian train 7200/8000
